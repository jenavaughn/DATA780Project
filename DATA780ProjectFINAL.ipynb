# %% [markdown]
# DATA 780 Project Jena K. Vaughn

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import folium
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# We will be using these functions

# %%
def timerange_check(dfname):
    df_copy = dfname.copy()
    df_copy['datetime'] = pd.to_datetime(df_copy['timestamp'], unit='s')

    print("Min:", df_copy['datetime'].min())
    print("Max:", df_copy['datetime'].max())
    return None

def get_coords(num):
  """
  Takes vessel # and returns all lat & lon coords for that vessel.
  num: Any number between 1-354. (Total # of ships)
  """
  ship_dfs = ship_dfs = {i+1: group.reset_index(drop=True)
            for i, (_, group) in enumerate(final_df.groupby('mmsi'))}
  lat = ship_dfs[num]['lat'].values
  long = ship_dfs[num]['lon'].values

  coords = [[lat[i], long[i]] for i in range(len(lat))]

  return coords

def map_ship_movements(num):
  """
  Takes vessel # and returns visualization of ship movements.
  num: Any number between 1-354. (Total # of ships)
  """
  coordinates = get_coords(num)

  m = folium.Map(location=[coordinates[0][0], coordinates[0][1]], zoom_start=5)

  trail_coordinates = coordinates

  folium.PolyLine(trail_coordinates, tooltip="Coast").add_to(m)
  return m

def map_ship_movements_chunk(num, n_coords=10):
    """
    Visualizes ship movement for a selected vessel.
    num: Ship number between 1-354.
    n_coords: Number of coordinates to plot from that ship's data.
    """
    coordinates = get_coords(num)

    trail_coordinates = coordinates[:n_coords]

    if len(trail_coordinates) == 0:
        print(f"No coordinates found for Ship #{num}")
        return None

    m = folium.Map(location=trail_coordinates[0], zoom_start=8)

    folium.PolyLine(trail_coordinates, tooltip=f'Ship #{num}').add_to(m)

    return m

def sample_mmsi_by_year(df, sample_size=10, year=2016):
  """
  Sample ships by year, seperated also by MMSI
  df: Dataframe (use final_df)
  sample_size: Number of ships sampled from each vessel_type
  year: Year to sample
  """
  dfs_sampled = []
  # Copy and preprocess the dataframe
  df_copy = df.copy()
  df_copy['datetime'] = pd.to_datetime(df_copy['timestamp'], unit='s')

  #Filter df for year and drop nan rows
  df_year = df_copy[df_copy['datetime'].dt.year == year].dropna()

  if df_year.empty:
    return pd.DataFrame()


  for vessel_type in df_year['vessel_type'].unique():
    #Filter df for the current vessel_type
    df_vessel_type = df_year[df_year['vessel_type'] == vessel_type]

    sampled_mmsi = df_vessel_type['mmsi'].drop_duplicates().sample(min(sample_size, df_vessel_type['mmsi'].nunique()),random_state=217)

    #Filter df to include only rows with the sampled mmsi
    df_sampled = df_vessel_type[df_vessel_type['mmsi'].isin(sampled_mmsi)]

    dfs_sampled.append(df_sampled)

    #Concat into df
  final_df = pd.concat(dfs_sampled, ignore_index=True)
  return final_df

def prep_data_for_cnn_non_overlap(df, sequence_length=10, feature_columns=['speed', 'distance_from_port', 'course', 'lat', 'lon'], label_column='vessel_type'):
    """
    Prepare data for CNN model. NON-OVERLAPPING SEQUENCES
    df: Input dataframe
    sequence_length: Choose a sequence length for timesteps
    feature_columns: List of features to use for prediction

    label_column: Target column to predict
    RETURNS:
    feature_sequences: Array of sequences of features; Shape = (batch_size, sequence_length, len(feature_columns))
    y_labels: Array of target labels (batch_size, )
    """
    df_copy = df.copy()

    df_copy['datetime'] = pd.to_datetime(df_copy['timestamp'], unit='s')

    latlon_data = df_copy[['lat', 'lon']].values
    other_features = df_copy[[col for col in feature_columns if col not in ['lat', 'lon']]].values

    scaler = MinMaxScaler()
    other_features = scaler.fit_transform(other_features)

    #Combine: lat/lon untouched, others normalized
    feature_data = np.concatenate([latlon_data, other_features], axis=1)

    #Non-overlapping sequences
    num_samples = len(df_copy) // sequence_length

    feature_sequences = []
    y_labels = []

    for i in range(num_samples):
        start_idx = i * sequence_length
        end_idx = start_idx + sequence_length

        sequence = feature_data[start_idx:end_idx]

        if len(sequence) == sequence_length:
            feature_sequences.append(sequence)
            y_labels.append(df_copy[label_column].iloc[end_idx - 1])

    feature_sequences = np.array(feature_sequences)
    y_labels = np.array(y_labels)

    return feature_sequences, y_labels


def prep_data_for_cnn_overlap(df, sequence_length=10, feature_columns=['speed', 'distance_from_port', 'course', 'lat', 'lon'], label_column='is_fishing'):
    """
    Prepare data for CNN model. OVERLAPPING SEQUENCES
    df: Input dataframe
    sequence_length: Choose a sequence length for timesteps
    feature_columns: List of features to use for prediction
    label_column: Target column to predict

    RETURNS:
    feature_sequences: Array of sequences of features; Shape = (batch_size, sequence_length, len(feature_columns))
    y_labels: Array of target labels (batch_size, )
    """
    df_copy = df.copy()

    if label_column == 'is_fishing':
        df_copy = df_copy[df_copy['is_fishing'] != -1]
        df_copy['is_fishing'] = df_copy['is_fishing'].apply(lambda x: round(x))

    if df_copy.empty:
        return np.array([]), np.array([])

    df_copy['datetime'] = pd.to_datetime(df_copy['timestamp'], unit='s')

    latlon_data = df_copy[['lat', 'lon']].values
    other_features = df_copy[[col for col in feature_columns if col not in ['lat', 'lon']]].values

    scaler = MinMaxScaler()
    other_features = scaler.fit_transform(other_features)

    feature_data = np.concatenate([latlon_data, other_features], axis=1)

    num_samples = len(df_copy) - sequence_length + 1

    feature_sequences = []
    y_labels = []

    for i in range(num_samples):
        start_idx = i
        end_idx = start_idx + sequence_length
        sequence = feature_data[start_idx:end_idx]

        if len(sequence) == sequence_length:
            feature_sequences.append(sequence)
            y_labels.append(df_copy[label_column].iloc[end_idx - 1])

    feature_sequences = np.array(feature_sequences)
    y_labels = np.array(y_labels)

    return feature_sequences, y_labels

# %% [markdown]
# Read in CSVs

# %%
df_drifting_longlines = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/drifting_longlines.csv")
df_fixed_gear = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/fixed_gear.csv")
df_pole_and_line = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/pole_and_line.csv")
df_purse_seines = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/purse_seines.csv")
df_trawlers = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/trawlers.csv")
df_trollers = pd.read_csv("/content/drive/MyDrive/DATA780Project_Vaughn/trollers.csv")

# %%
#Add column based on df
df_drifting_longlines['vessel_type'] = 0
df_fixed_gear['vessel_type'] = 1
df_pole_and_line['vessel_type'] = 2
df_purse_seines['vessel_type'] = 3
df_trawlers['vessel_type'] = 4
df_trollers['vessel_type'] = 5

list = [df_drifting_longlines, df_fixed_gear, df_pole_and_line, df_purse_seines, df_trawlers, df_trollers]
final_df = pd.concat(list, ignore_index=True).dropna() #Concat into big df

final_df.head()
# Out:
#            mmsi     timestamp  distance_from_shore  distance_from_port  speed  \
# 0  1.263956e+13  1.327137e+09        232994.281250        311748.65625    8.2
# 1  1.263956e+13  1.327137e+09        233994.265625        312410.34375    7.3
# 2  1.263956e+13  1.327137e+09        233994.265625        312410.34375    6.8
# 3  1.263956e+13  1.327143e+09        233994.265625        315417.37500    6.9
# 4  1.263956e+13  1.327143e+09        233996.390625        316172.56250    6.1
#
#        course        lat        lon  is_fishing               source  \
# 0  230.500000  14.865583 -26.853662        -1.0  dalhousie_longliner
# 1  238.399994  14.863870 -26.856800        -1.0  dalhousie_longliner
# 2  238.899994  14.861551 -26.860649        -1.0  dalhousie_longliner
# 3  251.800003  14.822686 -26.865898        -1.0  dalhousie_longliner
# 4  231.100006  14.821825 -26.867579        -1.0  dalhousie_longliner
#
#    vessel_type
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
#'is_fishin' = -1 means no data.  How much does our data shrink once we remove?

count_minusone = (final_df['is_fishing'] == -1).sum()
print(f"Number of -1 values in 'is_fishing' & proportion: {count_minusone} {count_minusone/len(final_df)*100:.2f}%. With {len(final_df)-count_minusone} left")
# Out:
# Number of -1 values in 'is_fishing' & proportion: 21295728 97.82%. With 473935 left

# %%
#Drop NaN rows & rows with -1; we will still retain ~500k samples
#Drop rows where 'is_fishing' is -1 and also drop rows with NaN values
df_cleaned = final_df[(final_df['is_fishing'] != -1)].dropna()

print(df_cleaned.shape)
# Out:
# (473935, 11)

# %%
#View movements
map_ship_movements(123)

#Uncomment the below to view smaller chunck
#map_ship_movements_chunk(123, 100) #First 100 movements
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_643ab132b499afd6a3b208ecc1c43a27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_643ab132b499afd6a3b208ecc1c43a27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_643ab132b499afd6a3b208ecc1c43a27 = L.map(
#                 &quot;map_643ab132b499afd6a3b208ecc1c43a27&quot;,
#                 {
#                     center: [43.5244522095, -1.5044599771],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf31be8a159938f057025d670a922024 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf31be8a159938f057025d670a922024.addTo(map_643ab132b499afd6a3b208ecc1c43a27);
#
#
#             var poly_line_b4c9ea8b68a214843fd7d10fabcd9aef = L.polyline(
#                 [[43.5244522095, -1.5044599771], [43.5244483948, -1.5044833422], [43.524433136000006, -1.5044599771], [43.524433136000006, -1.5044716597], [43.5244293213, -1.5044699907], [43.524394989, -1.5044933558000002], [43.524406433100005, -1.5045050383], [43.5244216919, -1.5044850111], [43.5244407654, -1.5044783354], [43.5243797302, -1.5044783354], [43.5244598389, -1.504529953], [43.5244140625, -1.5044900178999998], [43.5244293213, -1.5044816732], [43.5244102478, -1.5044800043000002], [43.5244216919, -1.5044833422], [43.5244216919, -1.5044649839], [43.5244255066, -1.5044649839], [43.524433136000006, -1.5044833422], [43.5244407654, -1.5044683218], [43.5244293213, -1.5044850111], [43.5244407654, -1.5044317244999998], [43.524471283, -1.5044783354], [43.524433136000006, -1.5044533014], [43.5244560242, -1.5044533014], [43.5244483948, -1.5044133663], [43.5244255066, -1.5044533014], [43.5243988037, -1.5044566393], [43.5244407654, -1.5044599771], [43.524433136000006, -1.5044449568], [43.5244369507, -1.5044733286], [43.524406433100005, -1.5044317244999998], [43.5244216919, -1.504463315], [43.5244407654, -1.5044599771], [43.5244178772, -1.5044499636000002], [43.5244026184, -1.5044200419999998], [43.5244216919, -1.5044332743000002], [43.5244483948, -1.5044766665], [43.5244598389, -1.5044499636000002], [43.524433136000006, -1.5044816732], [43.5244483948, -1.5044649839], [43.5244216919, -1.5044599771], [43.5244255066, -1.5044616461000002], [43.5244522095, -1.5044549704], [43.5244560242, -1.5044616461000002], [43.5243873596, -1.5045167208], [43.5244407654, -1.5044549704], [43.5244216919, -1.5044816732], [43.5244216919, -1.5044649839], [43.5244407654, -1.5044699907], [43.5244598389, -1.5044332743000002], [43.5244483948, -1.5044683218], [43.5244522095, -1.5044800043000002], [43.5244483948, -1.5044716597], [43.5244598389, -1.5044432878], [43.5244483948, -1.5044516325], [43.5244483948, -1.5044649839], [43.5244255066, -1.5045133829], [43.5244483948, -1.5044716597], [43.524433136000006, -1.5044466257], [43.5244483948, -1.5044300556], [43.3869934082, -1.6651450396], [43.3870201111, -1.6651366949000002], [43.3870010376, -1.6651583909999998], [43.3870048523, -1.6651400328], [43.3870277405, -1.6651616096], [43.387046814, -1.6651166677], [43.387046814, -1.665109992], [43.3870239258, -1.6651450396], [43.3870201111, -1.6651632786], [43.3870277405, -1.6651583909999998], [43.3870124817, -1.6651666164], [43.3869781494, -1.6652083397], [43.3870315552, -1.6651533842], [43.3870010376, -1.66517663], [43.3870277405, -1.6651417017], [43.3870277405, -1.6651500463], [43.3870315552, -1.6651467085], [43.387016296400006, -1.6651366949000002], [43.3870124817, -1.6651583909999998], [43.3870010376, -1.6651567221], [43.3862800598, -1.6654583216], [43.3857536316, -1.6648883819999998], [43.3857650757, -1.6648766994], [43.3996162415, -1.6704066992], [43.4276008606, -1.666826725], [43.4731254578, -1.6566482781999998], [43.51927948, -1.6471699476], [43.550174713100006, -1.6432483196], [43.5831871033, -1.6380532980000002], [43.6144218445, -1.6282149553], [43.6629219055, -1.6167249680000002], [43.6930847168, -1.6127333641], [43.7396202087, -1.6056166887], [43.772552490200006, -1.6018966436000002], [43.8209533691, -1.5966233015], [43.851371765100005, -1.5925049782], [43.8816146851, -1.5881099701], [43.9276313782, -1.5809999704], [43.956672668500005, -1.5762449503], [44.0008850098, -1.5683933496], [44.0308074951, -1.5614049435], [44.0649528503, -1.5535049438], [44.1850852966, -1.5019199848], [44.1529808044, -1.5061299801], [44.0983009338, -1.513011694], [44.0628242493, -1.5173699856], [44.025894165, -1.5209366083000002], [43.9961471558, -1.523516655], [43.9513130188, -1.5284366608000002], [43.905834198, -1.5353616475999998], [43.8609809875, -1.5450683831999998], [43.814414978, -1.5539466143], [43.7826728821, -1.5605733395], [43.75182724, -1.567258358], [43.7060813904, -1.5789666176], [43.6738128662, -1.5882833004], [43.6415481567, -1.5978950262], [43.5968551636, -1.61140501 ...

# %% [markdown]
# Model 1: 'vessel_type' classifcation for vessels in 2016

# %%
#Prep Data for sequence input; Use non overlaping sequences
test = sample_mmsi_by_year(final_df)

feature_seq, y = prep_data_for_cnn_non_overlap(test)

X_train, X_test, y_train, y_test = train_test_split(feature_seq, y, test_size=0.20, random_state=621)

# %%
#Check the shape of the resulting splits
print(f"Stratified Random Sample of vessels Shape: {test.shape}")
print(f"Train X shape: {X_train.shape}, Test X shape: {X_test.shape}")
print(f"Train Y shape: {y_train.shape}, Test Y shape: {y_test.shape}")
# Out:
# Stratified Random Sample of vessels Shape: (1336249, 12)
# Train X shape: (106899, 10, 5), Test X shape: (26725, 10, 5)
# Train Y shape: (106899,), Test Y shape: (26725,)

# %%
conv = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10, 5)),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax') #6 classes
])

#Compile model
conv.compile(
    optimizer=Adam(learning_rate=.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

#Fit
conv.fit(X_train, y_train, epochs=25, batch_size=32, validation_data=(X_test, y_test))

#Get accuracy
loss, accuracy = conv.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# Epoch 1/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.7465 - loss: 0.7111 - val_accuracy: 0.8337 - val_loss: 0.4303
# Epoch 2/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8402 - loss: 0.4018 - val_accuracy: 0.8563 - val_loss: 0.3608
# Epoch 3/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8582 - loss: 0.3432 - val_accuracy: 0.8462 - val_loss: 0.3503
# Epoch 4/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8707 - loss: 0.3117 - val_accuracy: 0.8752 - val_loss: 0.3017
# Epoch 5/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8854 - loss: 0.2800 - val_accuracy: 0.9029 - val_loss: 0.2770
# Epoch 6/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8942 - loss: 0.2566 - val_accuracy: 0.9018 - val_loss: 0.2460
# Epoch 7/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9080 - loss: 0.2320 - val_accuracy: 0.9106 - val_loss: 0.2151
# Epoch 8/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9161 - loss: 0.2147 - val_accuracy: 0.9266 - val_loss: 0.2027
# Epoch 9/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9232 - loss: 0.1996 - val_accuracy: 0.9305 - val_loss: 0.1801
# Epoch 10/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9295 - loss: 0.1856 - val_accuracy: 0.9374 - val_loss: 0.1663
# Epoch 11/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9330 - loss: 0.1775 - val_accuracy: 0.9339 - val_loss: 0.1734
# Epoch 12/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9361 - loss: 0.1682 - val_accuracy: 0.9361 - val_loss: 0.1787
# Epoch 13/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9408 - loss: 0.1600 - val_accuracy: 0.9334 - val_loss: 0.1597
# Epoch 14/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9425 - loss: 0.1522 - val_accuracy: 0.9445 - val_loss: 0.1453
# Epoch 15/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9440 - loss: 0.1476 - val_accuracy: 0.9490 - val_loss: 0.1308
# Epoch 16/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9456 - loss: 0.1440 - val_accuracy: 0.9503 - val_loss: 0.1340
# Epoch 17/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9466 - loss: 0.1397 - val_accuracy: 0.9474 - val_loss: 0.1387
# Epoch 18/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9491 - loss: 0.1330 - val_accuracy: 0.9451 - val_loss: 0.1437
# Epoch 19/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9501 - loss: 0.1301 - val_accuracy: 0.9544 - val_loss: 0.1254
# Epoch 20/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9515 - loss: 0.1245 - val_accuracy: 0.9536 - val_loss: 0.1160
# Epoch 21/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9535 - loss: 0.1196 - val_accuracy: 0.9573 - val_loss: 0.1112
# Epoch 22/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9526 - loss: 0.1209 - val_accuracy: 0.9440 - val_loss: 0.1371
# Epoch 23/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9548 - loss: 0.1158 - val_accuracy: 0.9566 - val_loss: 0.1232
# Epoch 24/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9543 - loss: 0.1160 - val_accuracy: 0.9474 - val_loss: 0.1293
# Epoch 25/25
# 3341/3341 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9562 - loss: 0.1120 - val_accuracy: 0.9610 - val_loss: 0.1048
# 836/836 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9590 - loss: 0.1063
# Test Loss: 0.10476744174957275, Test Accuracy: 0.9610102772712708

# %% [markdown]
# Model 2: 'is_fishing' classification

# %%
#Preprocess data; Important Note: Use overlap for this
feature_seq2, y2 = prep_data_for_cnn_overlap(final_df)

X_train, X_test, y_train, y_test = train_test_split(feature_seq2, y2, test_size=0.20, random_state=444)

print(f"Train X shape: {X_train.shape}, Test X shape: {X_test.shape}")
print(f"Train Y shape: {y_train.shape}, Test Y shape: {y_test.shape}")
# Out:
# Train X shape: (379140, 10, 5), Test X shape: (94786, 10, 5)
# Train Y shape: (379140,), Test Y shape: (94786,)

# %%
conv2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10, 5)), #Shape (seq_length, features)
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  #Same as previous model, just use sigmoid for binary classification
])

#Compile
conv2.compile(optimizer=Adam(learning_rate=.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
#Fit
conv2.fit(X_train, y_train, epochs=25, batch_size=64, validation_data=(X_test, y_test))

#Print accuracy
loss2, accuracy2 = conv2.evaluate(X_test, y_test)
print(f"Test Loss: {loss2}, Test Accuracy: {accuracy2}")
# Out:
# Epoch 1/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.6759 - loss: 0.6216 - val_accuracy: 0.7027 - val_loss: 0.5451
# Epoch 2/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.7459 - loss: 0.4960 - val_accuracy: 0.7854 - val_loss: 0.4310
# Epoch 3/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.7848 - loss: 0.4342 - val_accuracy: 0.7970 - val_loss: 0.4131
# Epoch 4/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8069 - loss: 0.3997 - val_accuracy: 0.8227 - val_loss: 0.3722
# Epoch 5/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8216 - loss: 0.3759 - val_accuracy: 0.8232 - val_loss: 0.3693
# Epoch 6/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8318 - loss: 0.3582 - val_accuracy: 0.8259 - val_loss: 0.3824
# Epoch 7/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.8423 - loss: 0.3412 - val_accuracy: 0.8311 - val_loss: 0.3623
# Epoch 8/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8477 - loss: 0.3302 - val_accuracy: 0.8325 - val_loss: 0.3439
# Epoch 9/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8578 - loss: 0.3175 - val_accuracy: 0.8632 - val_loss: 0.3066
# Epoch 10/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8639 - loss: 0.3069 - val_accuracy: 0.8507 - val_loss: 0.3158
# Epoch 11/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8681 - loss: 0.2994 - val_accuracy: 0.8693 - val_loss: 0.3076
# Epoch 12/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.8709 - loss: 0.2949 - val_accuracy: 0.8777 - val_loss: 0.2866
# Epoch 13/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8742 - loss: 0.2885 - val_accuracy: 0.8699 - val_loss: 0.2978
# Epoch 14/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8762 - loss: 0.2841 - val_accuracy: 0.8729 - val_loss: 0.2858
# Epoch 15/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8787 - loss: 0.2794 - val_accuracy: 0.8829 - val_loss: 0.2719
# Epoch 16/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8799 - loss: 0.2765 - val_accuracy: 0.8739 - val_loss: 0.2843
# Epoch 17/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8800 - loss: 0.2745 - val_accuracy: 0.8755 - val_loss: 0.2901
# Epoch 18/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8824 - loss: 0.2706 - val_accuracy: 0.8783 - val_loss: 0.2778
# Epoch 19/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8840 - loss: 0.2673 - val_accuracy: 0.8802 - val_loss: 0.2691
# Epoch 20/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8859 - loss: 0.2635 - val_accuracy: 0.8785 - val_loss: 0.2781
# Epoch 21/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8855 - loss: 0.2616 - val_accuracy: 0.8830 - val_loss: 0.2657
# Epoch 22/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8880 - loss: 0.2594 - val_accuracy: 0.8865 - val_loss: 0.2708
# Epoch 23/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8877 - loss: 0.2591 - val_accuracy: 0.8890 - val_loss: 0.2551
# Epoch 24/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8894 - loss: 0.2555 - val_accuracy: 0.8779 - val_loss: 0.2744
# Epoch 25/25
# 5925/5925 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.8909 - loss: 0.2518 - val_accuracy: 0.8900 - val_loss: 0.2544
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8891 - loss: 0.2558
# Test Loss: 0.2543643116950989, Test Accuracy: 0.8899943232536316

# %%
#Encode combined column for 'is_fishing' & 'vessel_type' combinations
df_cleanedv2 = df_cleaned.copy()
df_cleanedv2['is_fishing'] = df_cleanedv2['is_fishing'].round().astype(int)


mapping = {
    (0, 0): 0,
    (0, 1): 1,
    (0, 2): 2,
    (0, 3): 3,
    (0, 4): 4,
    (0, 5): 5,
    (1, 0): 6,
    (1, 1): 7,
    (1, 2): 8,
    (1, 3): 9,
    (1, 4): 10,
    (1, 5): 11,
}


df_cleanedv2['combined'] = df_cleanedv2.apply(lambda row: mapping.get((row['is_fishing'], row['vessel_type'])), axis=1)

# %% [markdown]
# Model 3: 'is_fishing' & 'vessel_type' classification

# %%
#Prep data with overlaping sequences
X, y = prep_data_for_cnn_overlap(df_cleanedv2, label_column='combined')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=999)

print(f"Train X shape: {X_train.shape}, Test X shape: {X_test.shape}")
print(f"Train Y shape: {y_train.shape}, Test Y shape: {y_test.shape}")
# Out:
# Train X shape: (379140, 10, 5), Test X shape: (94786, 10, 5)
# Train Y shape: (379140,), Test Y shape: (94786,)

# %%
conv3 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10, 5)),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    tf.keras.layers.MaxPooling1D(pool_size=3),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu', padding='same'),
    tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu', padding='same'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(256, kernel_size=3, activation='relu', padding='same'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(12, activation='softmax')  #'softmax' for 12 classes; similar structure to previous models with added 1Dconv layers
])

#Compile
conv3.compile(optimizer=Adam(learning_rate=.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']
)

#Fit
conv3.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test))

#Print accuracy
loss3, accuracy3 = conv3.evaluate(X_test, y_test)
print(f"Test Loss: {loss3}, Test Accuracy: {accuracy3}")
# Out:
# Epoch 1/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.5292 - loss: 1.1840 - val_accuracy: 0.5998 - val_loss: 0.9526
# Epoch 2/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6280 - loss: 0.8974 - val_accuracy: 0.6504 - val_loss: 0.8178
# Epoch 3/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6804 - loss: 0.7677 - val_accuracy: 0.6875 - val_loss: 0.7300
# Epoch 4/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7191 - loss: 0.6805 - val_accuracy: 0.7284 - val_loss: 0.6588
# Epoch 5/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7416 - loss: 0.6332 - val_accuracy: 0.7417 - val_loss: 0.6196
# Epoch 6/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7569 - loss: 0.6009 - val_accuracy: 0.7705 - val_loss: 0.5739
# Epoch 7/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7719 - loss: 0.5630 - val_accuracy: 0.7665 - val_loss: 0.5540
# Epoch 8/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7820 - loss: 0.5361 - val_accuracy: 0.7779 - val_loss: 0.5418
# Epoch 9/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7900 - loss: 0.5140 - val_accuracy: 0.7904 - val_loss: 0.5293
# Epoch 10/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7994 - loss: 0.4939 - val_accuracy: 0.7861 - val_loss: 0.5279
# Epoch 11/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8059 - loss: 0.4775 - val_accuracy: 0.8058 - val_loss: 0.4863
# Epoch 12/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8126 - loss: 0.4629 - val_accuracy: 0.7677 - val_loss: 0.6096
# Epoch 13/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8177 - loss: 0.4556 - val_accuracy: 0.8072 - val_loss: 0.4794
# Epoch 14/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8246 - loss: 0.4324 - val_accuracy: 0.8221 - val_loss: 0.4493
# Epoch 15/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8309 - loss: 0.4214 - val_accuracy: 0.8138 - val_loss: 0.4532
# Epoch 16/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8359 - loss: 0.4086 - val_accuracy: 0.7247 - val_loss: 0.6751
# Epoch 17/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8219 - loss: 0.4494 - val_accuracy: 0.8359 - val_loss: 0.4087
# Epoch 18/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8433 - loss: 0.3929 - val_accuracy: 0.8310 - val_loss: 0.4125
# Epoch 19/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8451 - loss: 0.3881 - val_accuracy: 0.8505 - val_loss: 0.3780
# Epoch 20/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8492 - loss: 0.3785 - val_accuracy: 0.8506 - val_loss: 0.3806
# Epoch 21/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8529 - loss: 0.3717 - val_accuracy: 0.8542 - val_loss: 0.3709
# Epoch 22/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8545 - loss: 0.3651 - val_accuracy: 0.8413 - val_loss: 0.3928
# Epoch 23/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8570 - loss: 0.3607 - val_accuracy: 0.8376 - val_loss: 0.4080
# Epoch 24/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8583 - loss: 0.3560 - val_accuracy: 0.8105 - val_loss: 0.4888
# Epoch 25/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8552 - loss: 0.3635 - val_accuracy: 0.8491 - val_loss: 0.3818
# Epoch 26/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8609 - loss: 0.3530 - val_accuracy: 0.8549 - val_loss: 0.3570
# Epoch 27/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8664 - loss: 0.3368 - val_accuracy: 0.8238 - val_loss: 0.4414
# Epoch 28/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8633 - loss: 0.3470 - val_accuracy: 0.8544 - val_loss: 0.3625
# Epoch 29/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8667 - loss: 0.3345 - val_accuracy: 0.8678 - val_loss: 0.3400
# Epoch 30/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8698 - loss: 0.3273 - val_accuracy: 0.8491 - val_loss: 0.3712
# Epoch 31/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8699 - loss: 0.3271 - val_accuracy: 0.8697 - val_loss: 0.3332
# Epoch 32/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8725 - loss: 0.3210 - val_accuracy: 0.8712 - val_loss: 0.3262
# Epoch 33/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8743 - loss: 0.3154 - val_accuracy: 0.8637 - val_loss: 0.3376
# Epoch 34/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8749 - loss: 0.3155 - val_accuracy: 0.8624 - val_loss: 0.3518
# Epoch 35/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8738 - loss: 0.3163 - val_accuracy: 0.8722 - val_loss: 0.3223
# Epoch 36/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8778 - loss: 0.3076 - val_accuracy: 0.8535 - val_loss: 0.3551
# Epoch 37/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8785 - loss: 0.3033 - val_accuracy: 0.8677 - val_loss: 0.3327
# Epoch 38/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8776 - loss: 0.3062 - val_accuracy: 0.8780 - val_loss: 0.3095
# Epoch 39/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8807 - loss: 0.2993 - val_accuracy: 0.8768 - val_loss: 0.3062
# Epoch 40/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8826 - loss: 0.2946 - val_accuracy: 0.8808 - val_loss: 0.3013
# Epoch 41/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8825 - loss: 0.2937 - val_accuracy: 0.8744 - val_loss: 0.3137
# Epoch 42/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8817 - loss: 0.2934 - val_accuracy: 0.8785 - val_loss: 0.3056
# Epoch 43/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8850 - loss: 0.2890 - val_accuracy: 0.8702 - val_loss: 0.3199
# Epoch 44/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8847 - loss: 0.2884 - val_accuracy: 0.8774 - val_loss: 0.3061
# Epoch 45/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8859 - loss: 0.2842 - val_accuracy: 0.8708 - val_loss: 0.3168
# Epoch 46/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8854 - loss: 0.2872 - val_accuracy: 0.8767 - val_loss: 0.3066
# Epoch 47/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8870 - loss: 0.2800 - val_accuracy: 0.8764 - val_loss: 0.3080
# Epoch 48/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8877 - loss: 0.2791 - val_accuracy: 0.8849 - val_loss: 0.2934
# Epoch 49/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8894 - loss: 0.2744 - val_accuracy: 0.8749 - val_loss: 0.3240
# Epoch 50/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8893 - loss: 0.2761 - val_accuracy: 0.8789 - val_loss: 0.3044
# Epoch 51/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8893 - loss: 0.2758 - val_accuracy: 0.8874 - val_loss: 0.2861
# Epoch 52/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8910 - loss: 0.2721 - val_accuracy: 0.8939 - val_loss: 0.2717
# Epoch 53/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8934 - loss: 0.2660 - val_accuracy: 0.8772 - val_loss: 0.3055
# Epoch 54/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8943 - loss: 0.2651 - val_accuracy: 0.8883 - val_loss: 0.2865
# Epoch 55/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8945 - loss: 0.2625 - val_accuracy: 0.8930 - val_loss: 0.2735
# Epoch 56/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8954 - loss: 0.2615 - val_accuracy: 0.8933 - val_loss: 0.2707
# Epoch 57/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8964 - loss: 0.2598 - val_accuracy: 0.8842 - val_loss: 0.2954
# Epoch 58/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8953 - loss: 0.2606 - val_accuracy: 0.8949 - val_loss: 0.2673
# Epoch 59/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8974 - loss: 0.2567 - val_accuracy: 0.8898 - val_loss: 0.2765
# Epoch 60/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8991 - loss: 0.2522 - val_accuracy: 0.8897 - val_loss: 0.2789
# Epoch 61/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8970 - loss: 0.2569 - val_accuracy: 0.8935 - val_loss: 0.2707
# Epoch 62/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8995 - loss: 0.2497 - val_accuracy: 0.8929 - val_loss: 0.2722
# Epoch 63/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9009 - loss: 0.2478 - val_accuracy: 0.8726 - val_loss: 0.3154
# Epoch 64/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8988 - loss: 0.2534 - val_accuracy: 0.8889 - val_loss: 0.2805
# Epoch 65/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9003 - loss: 0.2490 - val_accuracy: 0.8942 - val_loss: 0.2690
# Epoch 66/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9011 - loss: 0.2478 - val_accuracy: 0.8937 - val_loss: 0.2667
# Epoch 67/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9010 - loss: 0.2454 - val_accuracy: 0.8876 - val_loss: 0.2827
# Epoch 68/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9004 - loss: 0.2506 - val_accuracy: 0.8943 - val_loss: 0.2689
# Epoch 69/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9026 - loss: 0.2433 - val_accuracy: 0.8850 - val_loss: 0.2917
# Epoch 70/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9018 - loss: 0.2456 - val_accuracy: 0.8992 - val_loss: 0.2607
# Epoch 71/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9047 - loss: 0.2385 - val_accuracy: 0.8943 - val_loss: 0.2751
# Epoch 72/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9049 - loss: 0.2406 - val_accuracy: 0.9000 - val_loss: 0.2579
# Epoch 73/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9053 - loss: 0.2360 - val_accuracy: 0.9024 - val_loss: 0.2516
# Epoch 74/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9056 - loss: 0.2349 - val_accuracy: 0.9058 - val_loss: 0.2431
# Epoch 75/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9068 - loss: 0.2325 - val_accuracy: 0.8923 - val_loss: 0.2743
# Epoch 76/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9048 - loss: 0.2370 - val_accuracy: 0.8779 - val_loss: 0.3236
# Epoch 77/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9025 - loss: 0.2459 - val_accuracy: 0.8972 - val_loss: 0.2573
# Epoch 78/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9085 - loss: 0.2284 - val_accuracy: 0.9019 - val_loss: 0.2520
# Epoch 79/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9087 - loss: 0.2294 - val_accuracy: 0.9008 - val_loss: 0.2548
# Epoch 80/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9086 - loss: 0.2275 - val_accuracy: 0.9004 - val_loss: 0.2535
# Epoch 81/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9095 - loss: 0.2259 - val_accuracy: 0.9020 - val_loss: 0.2507
# Epoch 82/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9100 - loss: 0.2263 - val_accuracy: 0.9036 - val_loss: 0.2436
# Epoch 83/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9111 - loss: 0.2235 - val_accuracy: 0.9021 - val_loss: 0.2497
# Epoch 84/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9107 - loss: 0.2246 - val_accuracy: 0.9036 - val_loss: 0.2442
# Epoch 85/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9119 - loss: 0.2189 - val_accuracy: 0.9006 - val_loss: 0.2529
# Epoch 86/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9123 - loss: 0.2192 - val_accuracy: 0.9068 - val_loss: 0.2393
# Epoch 87/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9126 - loss: 0.2184 - val_accuracy: 0.8966 - val_loss: 0.2614
# Epoch 88/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9102 - loss: 0.2240 - val_accuracy: 0.9070 - val_loss: 0.2377
# Epoch 89/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9134 - loss: 0.2167 - val_accuracy: 0.9049 - val_loss: 0.2396
# Epoch 90/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9143 - loss: 0.2146 - val_accuracy: 0.9044 - val_loss: 0.2468
# Epoch 91/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9158 - loss: 0.2111 - val_accuracy: 0.9090 - val_loss: 0.2387
# Epoch 92/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9138 - loss: 0.2142 - val_accuracy: 0.9066 - val_loss: 0.2371
# Epoch 93/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9140 - loss: 0.2151 - val_accuracy: 0.9118 - val_loss: 0.2296
# Epoch 94/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9161 - loss: 0.2100 - val_accuracy: 0.9108 - val_loss: 0.2327
# Epoch 95/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9161 - loss: 0.2101 - val_accuracy: 0.9117 - val_loss: 0.2290
# Epoch 96/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9165 - loss: 0.2078 - val_accuracy: 0.9073 - val_loss: 0.2391
# Epoch 97/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9157 - loss: 0.2104 - val_accuracy: 0.9045 - val_loss: 0.2467
# Epoch 98/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9169 - loss: 0.2081 - val_accuracy: 0.9097 - val_loss: 0.2371
# Epoch 99/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9182 - loss: 0.2060 - val_accuracy: 0.9123 - val_loss: 0.2268
# Epoch 100/100
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9187 - loss: 0.2039 - val_accuracy: 0.9080 - val_loss: 0.2366
# 2963/2963 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9078 - loss: 0.2363
# Test Loss: 0.2366407960653305, Test Accuracy: 0.9080032706260681

# %%
#Compare models & their accuracy
conv.summary()
conv2.summary()
conv3.summary()

print(f'''Accruacy for Model 1:{accuracy}''')
print(f'''Accruacy for Model 1:{accuracy2}''')
print(f'''Accruacy for Model 1:{accuracy3}''')
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_83 (Conv1D)                   │ (None, 8, 64)               │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_84 (Conv1D)                   │ (None, 6, 64)               │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_33 (MaxPooling1D)      │ (None, 3, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_85 (Conv1D)                   │ (None, 1, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_25              │ (None, 128)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 6)                   │             390 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 140,180 (547.58 KB)
#  Trainable params: 46,726 (182.52 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 93,454 (365.06 KB)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_75 (Conv1D)                   │ (None, 8, 64)               │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_76 (Conv1D)                   │ (None, 6, 64)               │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_30 (MaxPooling1D)      │ (None, 3, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_77 (Conv1D)                   │ (None, 1, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_23              │ (None, 128)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_42 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_43 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 139,205 (543.77 KB)
#  Trainable params: 46,401 (181.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 92,804 (362.52 KB)
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_78 (Conv1D)                   │ (None, 10, 64)              │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_79 (Conv1D)                   │ (None, 10, 64)              │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_31 (MaxPooling1D)      │ (None, 3, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_80 (Conv1D)                   │ (None, 3, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_81 (Conv1D)                   │ (None, 3, 128)              │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_32 (MaxPooling1D)      │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_82 (Conv1D)                   │ (None, 1, 256)              │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_24              │ (None, 256)                 │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_44 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_45 (Dense)                     │ (None, 12)                  │             780 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 609,446 (2.32 MB)
#  Trainable params: 203,148 (793.55 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 406,298 (1.55 MB)
# Accruacy for Model 1:0.9610102772712708
# Accruacy for Model 1:0.8899943232536316
# Accruacy for Model 1:0.9080032706260681
